# %%
# %pylab inline
import pandas as pd
import numpy as np
from matplotlib import pyplot
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_pickle('../data/smooth_returnsDF.pkl')
symbolsDF = pd.read_pickle('../data/symbolsDF.pkl')

# %%
for column in df.columns:
    plot(np.cumprod(df[column]+1))

# %%
ser=df.mean(axis=1)
plot(ser.index,np.cumprod(ser+1))

# %%
data = df.copy()
data[pd.rolling_sum(data.shift(1), 6)>0]=0
ser=data.mean(axis=1)
plot(ser.index,np.cumprod(ser*3+1))

# %%
sectors = symbolsDF.sector.unique().tolist()

# %%
ls = symbolsDF[symbolsDF.sector=='financials'].index
ls.drop('ZION')
# Out:
# Index(['AFL', 'AMG', 'ALL', 'AXP', 'AIG', 'AMT', 'AMP', 'AON', 'AIV', 'AIZ',
#        'AVB', 'BAC', 'BK', 'BBT', 'BRK-B', 'BLK', 'HRB', 'BXP', 'COF', 'CBG',
#        'SCHW', 'CB', 'CINF', 'C', 'CME', 'CMA', 'CCI', 'DFS', 'ETFC', 'EFX',
#        'EQR', 'ESS', 'EXR', 'FRT', 'FITB', 'BEN', 'GGP', 'GS', 'HIG', 'HCP',
#        'HST', 'HBAN', 'ICE', 'IVZ', 'JPM', 'KEY', 'KIM', 'LM', 'LUK', 'LNC',
#        'L', 'MTB', 'MAC', 'MMC', 'MHFI', 'MET', 'MCO', 'MS', 'NDAQ', 'NAVI',
#        'NTRS', 'PBCT', 'PNC', 'CFG', 'PFG', 'PGR', 'PLD', 'PRU', 'PSA', 'O',
#        'RF', 'SPG', 'SLG', 'STT', 'STI', 'SYF', 'TROW', 'TRV', 'TMK', 'UDR',
#        'USB', 'UNM', 'VTR', 'VNO', 'WFC', 'HCN', 'WY', 'WLTW', 'XL'],
#       dtype='object', name='symbols')

# %%
for sector_ in sectors:
    print(sector_)
    ls = symbolsDF[symbolsDF.sector==sector_].index
    try:
        ser = df[ls].mean(axis=1)
    except:
        ser = df[ls.drop('WLTW')].mean(axis=1)
    plot(ser.index,np.cumprod(ser+1))
    show()
# Out:
# telecommunications_services
# energy
# information_technology
# utilities
# materials
# consumer_staples
# financials
# health_care
# industrials
# consumer_discretionary

# %%
for sector_ in sectors:
    print(sector_)
    ls = symbolsDF[symbolsDF.sector==sector_].index
    try:
        ser = df[ls].mean(axis=1)
    except:
        ser = df[ls.drop('WLTW')].mean(axis=1)
    data[pd.rolling_sum(data.shift(1), 6)>0]=0
    ser=data.mean(axis=1)
    plot(ser.index,np.cumprod(ser+1))
    show()
# Out:
# telecommunications_services
# energy
# information_technology
# utilities
# materials
# consumer_staples
# financials
# health_care
# industrials
# consumer_discretionary
