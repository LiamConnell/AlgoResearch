# %%
# %pylab inline
import pandas as pd
import numpy as np
from matplotlib import pyplot
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_pickle('../data/kal_returnsDF.pkl')

# %%
ser=df.mean(axis=1)
plot(ser.index,np.cumprod(ser+1))

# %%
data = df.copy()
data[pd.rolling_sum(data.shift(1), 6)>0]=0
ser=data.mean(axis=1)
plot(ser.index,np.cumprod(ser*3+1))

# %%
numpos = sum(pd.rolling_sum(data, 100)<0, axis=1)

# %%
plot(numpos)

# %%
ser['2009'].index
# Out:
# DatetimeIndex(['2009-01-02', '2009-01-05', '2009-01-06', '2009-01-07',
#                '2009-01-08', '2009-01-09', '2009-01-12', '2009-01-13',
#                '2009-01-14', '2009-01-15',
#                ...
#                '2009-12-17', '2009-12-18', '2009-12-21', '2009-12-22',
#                '2009-12-23', '2009-12-24', '2009-12-28', '2009-12-29',
#                '2009-12-30', '2009-12-31'],
#               dtype='datetime64[ns]', name='Date', length=252, freq=None, tz=None)

# %%
# Out:
# -0.032616225072815211
