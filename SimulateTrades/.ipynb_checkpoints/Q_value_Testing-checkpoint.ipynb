# %%
# %pylab inline
import pandas as pd
import numpy as np
from matplotlib import pyplot
import seaborn
import os, re
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_pickle('../data/kal_returnsDF.pkl')
symbolsDF = pd.read_pickle('../data/symbolsDF.pkl')
sectors = symbolsDF.sector.unique().tolist()

# %%
start, end = '2007-05-02', '2016-04-11'                        #variable here
datadir_name = '_'.join(('data', start, end))
datadir_path = ''.join(('../data/', datadir_name))

# %%
def get_symbol_results(symbol='GS'):
    df = pd.read_pickle(''.join((datadir_path, '/', symbol, '.pkl')))
    return df
df = get_symbol_results()

# %%
gs = get_symbol_results(symbol='GS')

# %%
np.cumprod(df.kal_returns+1).plot(label="equity curve", legend=True, 
                                  title='Tear Sheet', figsize=(14,6))
df['Adj Close'].plot(secondary_y=True, label="price", legend=True)
df.kalman_predict.plot(secondary_y=True, label="filter", legend=True)

# %%
np.cumprod(df.kal_returns+1).plot(label="equity curve", legend=True, 
                                  title='Tear Sheet', figsize=(14,6))
df['Adj Close'].plot(secondary_y=True, label="price", legend=True)
plot(secondary_y=True, label="filter", legend=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-faababd9b42f> in <module>()
#       2                                   title='Tear Sheet', figsize=(14,6))
#       3 df['Adj Close'].plot(secondary_y=True, label="price", legend=True)
# ----> 4 plot(xs[:,0], secondary_y=True, label="filter", legend=True)
#
# /Users/liamconnell/anaconda/lib/python3.4/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3097         ax.hold(hold)
#    3098     try:
# -> 3099         ret = ax.plot(*args, **kwargs)
#    3100         draw_if_interactive()
#    3101     finally:
#
# /Users/liamconnell/anaconda/lib/python3.4/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1371         lines = []
#    1372
# -> 1373         for line in self._get_lines(*args, **kwargs):
#    1374             self.add_line(line)
#    1375             lines.append(line)
#
# /Users/liamconnell/anaconda/lib/python3.4/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     302                 return
#     303             if len(remaining) <= 3:
# --> 304                 for seg in self._plot_args(remaining, kwargs):
#     305                     yield seg
#     306                 return
#
# /Users/liamconnell/anaconda/lib/python3.4/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     290         ncx, ncy = x.shape[1], y.shape[1]
#     291         for j in xrange(max(ncx, ncy)):
# --> 292             seg = func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     293             ret.append(seg)
#     294         return ret
#
# /Users/liamconnell/anaconda/lib/python3.4/site-packages/matplotlib/axes/_base.py in _makeline(self, x, y, kw, kwargs)
#     242                             **kw
#     243                             )
# --> 244         self.set_lineprops(seg, **kwargs)
#     245         return seg
#     246
#
# /Users/liamconnell/anaconda/lib/python3.4/site-packages/matplotlib/axes/_base.py in set_lineprops(self, line, **kwargs)
#     182             funcName = "set_%s" % key
#     183             if not hasattr(line, funcName):
# --> 184                 raise TypeError('There is no line property "%s"' % key)
#     185             func = getattr(line, funcName)
#     186             func(val)
#
# TypeError: There is no line property "legend"

# %%
os.chdir('../GetBasicData/')
import smoothing_fns as sf

# %%
xs, cov = sf.run(data = df)

# %%
plot(xs[:,0])

# %%
ser = pd.Series(xs[:,0])
