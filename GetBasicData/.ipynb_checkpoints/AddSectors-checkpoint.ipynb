# %%
from urllib.request import Request
from urllib.request import urlopen
import pytz
import pandas as pd

from bs4 import BeautifulSoup
from datetime import datetime
from pandas.io.data import DataReader

# %%
site = SITE = "http://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

# %%
hdr = {'User-Agent': 'Mozilla/5.0'}
req = Request(site, headers=hdr)
page = urlopen(req)
soup = BeautifulSoup(page)
# Out:
# /Users/liamconnell/anaconda/lib/python3.4/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
def scrape_list(site):
    hdr = {'User-Agent': 'Mozilla/5.0'}
    req = Request(site, headers=hdr)
    page = urlopen(req)
    soup = BeautifulSoup(page)

    table = soup.find('table', {'class': 'wikitable sortable'})
    sector_tickers = dict()
    for row in table.findAll('tr'):
        col = row.findAll('td')
        if len(col) > 0:
            sector = str(col[3].string.strip()).lower().replace(' ', '_')
            ticker = str(col[0].string.strip())
            if sector not in sector_tickers:
                sector_tickers[sector] = list()
            sector_tickers[sector].append(ticker)
    return sector_tickers

# %%
ls = scrape_list(SITE)
# Out:
# /Users/liamconnell/anaconda/lib/python3.4/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
symbolsDF = pd.read_pickle('../data/symbolsDF.pkl')

# %%
symbolsDF['sector'] = ''
for key in ls.keys():
    print(key)
    syms = ls[key]
    for sym in syms:
        if sym in symbolsDF.index:
            symbolsDF.loc[sym, 'sector'] = key
# Out:
# energy
# industrials
# telecommunications_services
# health_care
# information_technology
# utilities
# consumer_staples
# materials
# consumer_discretionary
# financials

# %%
symbolsDF
# Out:
#         symbols smooth regr kalman smoothing_fns_logic kal_logic      sector
# symbols
# AES         AES        True   True                True      True   utilities
# GAS         GAS        True   True                True      True   utilities
# AEE         AEE        True   True                True      True   utilities
# AEP         AEP        True   True                True      True   utilities
# AWK         AWK        True   True                True      True   utilities
# CNP         CNP        True   True                True      True   utilities
# CMS         CMS        True   True                True      True   utilities
# ED           ED        True   True                True      True   utilities
# D             D        True   True                True      True   utilities
# DTE         DTE        True   True                True      True   utilities
# DUK         DUK        True   True                True      True   utilities
# EIX         EIX        True   True                True      True   utilities
# ETR         ETR        True   True                True      True   utilities
# ES           ES        True   True                True      True   utilities
# EXC         EXC        True   True                True      True   utilities
# FE           FE        True   True                True      True   utilities
# NEE         NEE        True   True                True      True   utilities
# NI           NI        True   True                True      True   utilities
# NRG         NRG        True   True                True      True   utilities
# PCG         PCG        True   True                True      True   utilities
# PNW         PNW        True   True                True      True   utilities
# PPL         PPL        True   True                True      True   utilities
# PEG         PEG        True   True                True      True   utilities
# SCG         SCG        True   True                True      True   utilities
# SRE         SRE        True   True                True      True   utilities
# SO           SO        True   True                True      True   utilities
# TE           TE        True   True                True      True   utilities
# WEC         WEC        True   True                True      True   utilities
# XEL         XEL        True   True                True      True   utilities
# APC         APC        True   True                True      True      energy
# ...         ...         ...    ...                 ...       ...         ...
# NTRS       NTRS        True   True                True      True  financials
# PBCT       PBCT        True   True                True      True  financials
# PNC         PNC        True   True                True      True  financials
# CFG         CFG        True   True                True      True  financials
# PFG         PFG        True   True                True      True  financials
# PGR         PGR        True   True                True      True  financials
# PLD         PLD        True   True                True      True  financials
# PRU         PRU        True   True                True      True  financials
# PSA         PSA        True   True                True      True  financials
# O             O        True   True                True      True  financials
# RF           RF        True   True                True      True  financials
# SPG         SPG        True   True                True      True  financials
# SLG         SLG        True   True                True      True  financials
# STT         STT        True   True                True      True  financials
# STI         STI        True   True                True      True  financials
# SYF         SYF        True   True                True      True  financials
# TROW       TROW        True   True                True      True  financials
# TRV         TRV        True   True                True      True  financials
# TMK         TMK        True   True                True      True  financials
# UDR         UDR        True   True                True      True  financials
# USB         USB        True   True                True      True  financials
# UNM         UNM        True   True                True      True  financials
# VTR         VTR        True   True                True      True  financials
# VNO         VNO        True   True                True      True  financials
# WFC         WFC        True   True                True      True  financials
# HCN         HCN        True   True                True      True  financials
# WY           WY        True   True                True      True  financials
# WLTW       WLTW       False   True               False      True  financials
# XL           XL        True   True                True      True  financials
# ZION       ZION        True   True                True      True  financials
#
# [504 rows x 6 columns]

# %%
symbolsDF.to_pickle('../data/symbolsDF.pkl')
