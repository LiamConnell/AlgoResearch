# %%
from urllib.request import Request
from urllib.request import urlopen
import pytz
import pandas as pd

from bs4 import BeautifulSoup
from datetime import datetime
from pandas.io.data import DataReader

# %%
site = SITE = "http://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

# %%
def scrape_list(site):
    hdr = {'User-Agent': 'Mozilla/5.0'}
    req = Request(site, headers=hdr)
    page = urlopen(req)
    soup = BeautifulSoup(page)

    table = soup.find('table', {'class': 'wikitable sortable'})
    sector_tickers = dict()
    for row in table.findAll('tr'):
        col = row.findAll('td')
        if len(col) > 0:
            sector = str(col[3].string.strip()).lower().replace(' ', '_')
            ticker = str(col[0].string.strip())
            if sector not in sector_tickers:
                sector_tickers[sector] = list()
            sector_tickers[sector].append(ticker)
    return sector_tickers

# %%
ls = scrape_list(SITE)
# Out:
# /Users/liamconnell/anaconda/lib/python3.4/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
symbolsDF = pd.read_pickle('../data/symbolsDF.pkl')

# %%
symbolsDF['sector'] = ''
for key in ls.keys():
    print(key)
    syms = ls[key]
    for sym in syms:
        if sym in symbolsDF.index:
            symbolsDF.loc[sym, 'sector'] = key
# Out:
# telecommunications_services
# industrials
# consumer_staples
# consumer_discretionary
# utilities
# materials
# energy
# financials
# information_technology
# health_care

# %%
symbolsDF
# Out:
#         symbols data_2007-05-02_2016-04-11                       sector  \
# symbols
# T             T                       True  telecommunications_services
# CTL         CTL                       True  telecommunications_services
# FTR         FTR                       True  telecommunications_services
# LVLT       LVLT                       True  telecommunications_services
# VZ           VZ                       True  telecommunications_services
# APC         APC                       True                       energy
# APA         APA                       True                       energy
# BHI         BHI                       True                       energy
# COG         COG                       True                       energy
# CHK         CHK                       True                       energy
# CVX         CVX                       True                       energy
# XEC         XEC                       True                       energy
# CPGX       CPGX                       True                       energy
# CXO         CXO                       True                       energy
# COP         COP                       True                       energy
# DVN         DVN                       True                       energy
# DO           DO                       True                       energy
# EOG         EOG                       True                       energy
# EQT         EQT                       True                       energy
# XOM         XOM                       True                       energy
# FTI         FTI                       True                       energy
# HAL         HAL                       True                       energy
# HP           HP                       True                       energy
# HES         HES                       True                       energy
# KMI         KMI                       True                       energy
# MRO         MRO                       True                       energy
# MPC         MPC                       True                       energy
# MUR         MUR                       True                       energy
# NOV         NOV                       True                       energy
# NFX         NFX                       True                       energy
# ...         ...                        ...                          ...
# PVH         PVH                       True       consumer_discretionary
# ROST       ROST                       True       consumer_discretionary
# RCL         RCL                       True       consumer_discretionary
# SNI         SNI                       True       consumer_discretionary
# SIG         SIG                       True       consumer_discretionary
# SNA         SNA                       True       consumer_discretionary
# SWK         SWK                       True       consumer_discretionary
# SPLS       SPLS                       True       consumer_discretionary
# SBUX       SBUX                       True       consumer_discretionary
# HOT         HOT                       True       consumer_discretionary
# TGT         TGT                       True       consumer_discretionary
# TGNA       TGNA                       True       consumer_discretionary
# TIF         TIF                       True       consumer_discretionary
# TWX         TWX                       True       consumer_discretionary
# TWC         TWC                       True       consumer_discretionary
# TJX         TJX                       True       consumer_discretionary
# TSCO       TSCO                       True       consumer_discretionary
# TRIP       TRIP                       True       consumer_discretionary
# FOXA       FOXA                       True       consumer_discretionary
# FOX         FOX                       True       consumer_discretionary
# ULTA       ULTA                       True       consumer_discretionary
# UA           UA                       True       consumer_discretionary
# URBN       URBN                       True       consumer_discretionary
# VFC         VFC                       True       consumer_discretionary
# VIAB       VIAB                       True       consumer_discretionary
# DIS         DIS                       True       consumer_discretionary
# WHR         WHR                       True       consumer_discretionary
# WYN         WYN                       True       consumer_discretionary
# WYNN       WYNN                       True       consumer_discretionary
# YUM         YUM                       True       consumer_discretionary
#
#         smooth regr kalman
# symbols
# T              True   True
# CTL            True   True
# FTR            True   True
# LVLT           True   True
# VZ             True   True
# APC            True   True
# APA            True   True
# BHI            True   True
# COG            True   True
# CHK            True   True
# CVX            True   True
# XEC            True   True
# CPGX           True   True
# CXO            True   True
# COP            True   True
# DVN            True   True
# DO             True   True
# EOG            True   True
# EQT            True   True
# XOM            True   True
# FTI            True   True
# HAL            True   True
# HP             True   True
# HES            True   True
# KMI            True   True
# MRO            True   True
# MPC            True   True
# MUR            True   True
# NOV            True   True
# NFX            True   True
# ...             ...    ...
# PVH            True   True
# ROST           True   True
# RCL            True   True
# SNI            True   True
# SIG            True   True
# SNA            True   True
# SWK            True   True
# SPLS           True   True
# SBUX           True   True
# HOT            True   True
# TGT            True   True
# TGNA           True   True
# TIF            True   True
# TWX            True   True
# TWC            True   True
# TJX            True   True
# TSCO           True   True
# TRIP           True   True
# FOXA           True   True
# FOX            True   True
# ULTA           True   True
# UA             True   True
# URBN           True   True
# VFC            True   True
# VIAB           True   True
# DIS            True   True
# WHR            True   True
# WYN            True   True
# WYNN           True   True
# YUM            True   True
#
# [504 rows x 5 columns]

# %%
symbolsDF.to_pickle('../data/symbolsDF.pkl')
